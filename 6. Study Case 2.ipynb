# %% [markdown]
# Studi kasus tentang percabangan

# %%
Studi Kasus 1

Arduino mengecek level air di tangki.

logika
5 persen = air kosong
20 persen = air sedikit
50 persen = air setengah
75 persen = air berada di titik aman
95 persen = tangki penuh

# %% [markdown]
# Studi Kasus 2
#
# Arduino membaca suhu ruangan dan menentukan kondisi AC.
#
# Cara Berpikir Logis :
# - Ada lebih dari dua kemungkinan
# - Harus dicek berurutan
# - Jika semua kondisi gagal → kondisi terakhir (else)
#
# note :
# - suhu >= 33 ac maksimal
# - Suhu >= 28 ac normal
# - suhu >= 22 ac rendah
# - ac mati

# %% [markdown]
# Studi Kasus 3
#
# Arduino menerima kode status mesin dan menampilkan pesan.
#
# Cara Berpikir Logis :
#
# - Banyak nilai tetap
# - Tidak pakai perbandingan (> <)
# - Lebih efisien dan jelas
#
# note
# - mesin siap
# - mesin beroperasi
# - mesin overheat
# - mesin eror
# - status tidak dikenal

# %% [markdown]
# Studi Kasus 4
# Sistem Penilaian Kelayakan Daya Listrik
#
# Arduino mengevaluasi kelayakan daya listrik berdasarkan:
# - Tegangan
# - Arus
# - Suhu kabel
#
# Cara Berpikir Logis
#
# - Kondisi paling berbahaya harus diprioritaskan
# - Tidak cukup satu parameter
# - Kesalahan urutan = hasil salah
#
# note
# - tegangan < 180 || tegangan > 240
# - BAHAYA: Kabel overheating
# - Peringatan: Arus tinggi
# - Sistem listrik norma

# %% [markdown]
# Studi Kasus 5
#
# Sistem Menu Konfigurasi Alat
#
# Arduino menerima kode menu dan menjalankan fungsi konfigurasi berbeda.
#
# (menggunakan switch)
# note :
#  kalibrasi sensor
#  reset data
#  tes sistem
#  mode produksi
#  mode maintenance
#  menu tidak tersedia
